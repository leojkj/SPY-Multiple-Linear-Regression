# %%
import yfinance as yf
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
#importing data from yahoo finance
SPY = yf.Ticker('SPY')

# %%
SPY = pd.DataFrame(SPY.history(period = '10y'))

# %%
SPY.index = pd.to_datetime(SPY.index)
SPY.index = SPY.index.date
SPY.head()
# Out:
#                  Close        High         Low        Open    Volume  \
# 2014-06-20         NaN         NaN         NaN         NaN         0
# 2014-06-23  164.483170  164.625919  164.180872  164.575539  70611000
# 2014-06-24  163.492264  165.003751  163.307526  164.189228  96237000
# 2014-06-25  164.231262  164.399202  163.114441  163.148024  82782000
# 2014-06-26  164.113754  164.273302  163.013731  164.256504  84312000
#
#             Dividends  Stock Splits  Capital Gains
# 2014-06-20      0.937           0.0            0.0
# 2014-06-23      0.000           0.0            0.0
# 2014-06-24      0.000           0.0            0.0
# 2014-06-25      0.000           0.0            0.0
# 2014-06-26      0.000           0.0            0.0

# %%
SPY.dtypes
# Out:
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# Dividends        float64
# Stock Splits     float64
# Capital Gains    float64
# dtype: object

# %%
plt.figure(figsize=(15, 8))
plt.plot(SPY['Close'], alpha=0.7, color='blue')

# %%
AORD = yf.Ticker('^AORD')
HSI = yf.Ticker('^HSI')   
Nikkei = yf.Ticker('^N225') 
CAC40 = yf.Ticker('^FCHI')
DAX = yf.Ticker('^GDAXI')
SP500 = yf.Ticker('^GSPC') 
NASDAQ = yf.Ticker('^IXIC')
DJI = yf.Ticker('^DJI')

# %%
#I want to us indices from other markets to create a prediction model for SPY
#Asian Market: Aord, HSI, Nikkei
#EU: CAC40, DAX
#US: S&P500, NASDAQ, DJI 
AORD = pd.DataFrame(AORD.history('10y'))  
HSI = pd.DataFrame(HSI.history('10y'))
Nikkei = pd.DataFrame(Nikkei.history('10y'))
CAC40 = pd.DataFrame(CAC40.history('10y')) 
DAX = pd.DataFrame(DAX.history('10y')) 
SP500 = pd.DataFrame(SP500.history('10y'))  
NASDAQ = pd.DataFrame(NASDAQ.history('10y'))     
DJI = pd.DataFrame(DJI.history('10y'))
#We will create a multiple linear regression model to predict the next day open price.
#Using the difference of open next day-open for SPY
#Then I am using the difference of open-open last day for the us and eu market 
#Lastly I will use the difference of the close-open prices from the asian market
#Difference between today's and yesterday's open prices for US and EU market helps me gauge how overnight changes in these markets might influence investor sentiment and trading activity in SPY at its open.

# %%
AORD.index = pd.to_datetime(AORD.index)
AORD.index = AORD.index.date
HSI.index = pd.to_datetime(HSI.index)
HSI.index = HSI.index.date
Nikkei.index = pd.to_datetime(Nikkei.index)
Nikkei.index = Nikkei.index.date
CAC40.index = pd.to_datetime(CAC40.index)
CAC40.index = CAC40.index.date
DAX.index = pd.to_datetime(DAX.index)
DAX.index = DAX.index.date
SP500.index = pd.to_datetime(SP500.index)
SP500.index = SP500.index.date
NASDAQ.index = pd.to_datetime(NASDAQ.index)
NASDAQ.index = NASDAQ.index.date
DJI.index = pd.to_datetime(DJI.index)
DJI.index = DJI.index.date

# %%
indicepanel = pd.DataFrame(index=SPY.index)
indicepanel['SPY'] = SPY['Open'].shift(-1) - SPY['Open']
indicepanel['SPY_lag1'] = indicepanel['SPY'].shift(1)
indicepanel['SP500'] = SP500['Open'] - SP500['Open'].shift(1)
indicepanel['NASDAQ'] = NASDAQ['Open'] - NASDAQ['Open'].shift(1)
indicepanel['DJI'] = DJI['Open'] - DJI['Open'].shift(1)

indicepanel['CAC40'] = CAC40['Open'] - CAC40['Open'].shift(1)
indicepanel['DAX'] = DAX['Open'] - DAX['Open'].shift(1)

indicepanel['AORD'] = AORD['Close'] - AORD['Open']
indicepanel['HSI'] = HSI['Close'] - HSI['Open']
indicepanel['Nikkei'] = Nikkei['Close'] - Nikkei['Open']

indicepanel['Price'] = SPY['Open']

# %%
#From our data the NaN is present 
#We can try an fill the NaN values with the values from the previous row using fill forward
indicepanel.ffill(inplace=True)  # ffill = Forward fill NaN values
indicepanel.head()
# Out:
#                  SPY  SPY_lag1      SP500     NASDAQ         DJI      CAC40  \
# 2014-06-20       NaN       NaN        NaN        NaN         NaN        NaN
# 2014-06-23 -0.386311       NaN        NaN        NaN         NaN -14.989746
# 2014-06-24 -1.041204 -0.386311  -0.950073  -1.060059  -11.880859 -10.979980
# 2014-06-25  1.108480 -1.041204 -12.699951 -26.080078 -116.939453 -35.180176
# 2014-06-26 -0.529058  1.108480  10.619995  37.620117   49.130859 -23.580078
#
#                   DAX       AORD         HSI     Nikkei       Price
# 2014-06-20        NaN        NaN         NaN        NaN         NaN
# 2014-06-23  -4.099609  31.100098 -360.449219 -50.189453  164.575539
# 2014-06-24 -52.760742 -17.600098  -35.279297  75.740234  164.189228
# 2014-06-25 -54.859375 -28.300293  -68.361328 -30.629883  163.148024
# 2014-06-26  10.769531  60.000000  249.990234 -11.639648  164.256504

# %%
indicepanel = indicepanel.dropna()
indicepanel.head()
# Out:
#                  SPY  SPY_lag1      SP500     NASDAQ         DJI      CAC40  \
# 2014-06-24 -1.041204 -0.386311  -0.950073  -1.060059  -11.880859 -10.979980
# 2014-06-25  1.108480 -1.041204 -12.699951 -26.080078 -116.939453 -35.180176
# 2014-06-26 -0.529058  1.108480  10.619995  37.620117   49.130859 -23.580078
# 2014-06-27  0.604618 -0.529058  -3.329956  -7.640137  -19.910156 -23.609863
# 2014-06-30  0.419809  0.604618   4.229980  26.570312    5.589844  -4.140137
#
#                   DAX       AORD         HSI      Nikkei       Price
# 2014-06-24 -52.760742 -17.600098  -35.279297   75.740234  164.189228
# 2014-06-25 -54.859375 -28.300293  -68.361328  -30.629883  163.148024
# 2014-06-26  10.769531  60.000000  249.990234  -11.639648  164.256504
# 2014-06-27 -76.089844 -17.699707   33.039062 -195.750000  163.727446
# 2014-06-30  15.389648 -47.100098  -82.468750    2.649414  164.332064

# %%
#cleaned our data so that with preserved continuity while having no NaN
indicepanel.shape
# Out:
# (2515, 11)

# %%
indicepanel.corr()
# Out:
#                SPY  SPY_lag1     SP500    NASDAQ       DJI     CAC40  \
# SPY       1.000000 -0.050495 -0.020282 -0.029895 -0.024173 -0.037667
# SPY_lag1 -0.050495  1.000000  0.935813  0.926390  0.825410  0.536726
# SP500    -0.020282  0.935813  1.000000  0.886185  0.907616  0.573849
# NASDAQ   -0.029895  0.926390  0.886185  1.000000  0.685867  0.456530
# DJI      -0.024173  0.825410  0.907616  0.685867  1.000000  0.595564
# CAC40    -0.037667  0.536726  0.573849  0.456530  0.595564  1.000000
# DAX      -0.051619  0.530332  0.560016  0.460578  0.576657  0.891222
# AORD     -0.013986  0.517102  0.506571  0.433181  0.509491  0.617438
# HSI      -0.072396  0.146325  0.076954  0.148480  0.050975  0.211197
# Nikkei    0.024794  0.250540  0.217397  0.225184  0.203068  0.363850
# Price     0.012323  0.043295  0.043216  0.032771  0.021705  0.017569
#
#                DAX      AORD       HSI    Nikkei     Price
# SPY      -0.051619 -0.013986 -0.072396  0.024794  0.012323
# SPY_lag1  0.530332  0.517102  0.146325  0.250540  0.043295
# SP500     0.560016  0.506571  0.076954  0.217397  0.043216
# NASDAQ    0.460578  0.433181  0.148480  0.225184  0.032771
# DJI       0.576657  0.509491  0.050975  0.203068  0.021705
# CAC40     0.891222  0.617438  0.211197  0.363850  0.017569
# DAX       1.000000  0.606956  0.209411  0.378376  0.021128
# AORD      0.606956  1.000000  0.156362  0.325046  0.014522
# HSI       0.209411  0.156362  1.000000  0.234272  0.001627
# Nikkei    0.378376  0.325046  0.234272  1.000000  0.031832
# Price     0.021128  0.014522  0.001627  0.031832  1.000000

# %%
indicepanel.to_csv("D:\downloads\Data\indicepanel.csv")

# %%
#Creating a corr matrix heatmap
import seaborn as sns

plt.figure(figsize = (10, 4))
heatmap = sns.heatmap(indicepanel.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %%
#There are no signs of the stock being correlated with SPY but the lag value provides some correlation with the other stocks.
#Could suggest that the lag prices of SPY corresponds to the increase in the other stock values.
from pandas.plotting import scatter_matrix
scatter_matrix = scatter_matrix(indicepanel, figsize=(10,10))

# %%
start = dt.date(2020, 1, 1)
end = dt.date(2022, 6, 13)

training_data = indicepanel.loc[start:end]

training_data.tail()
# Out:
#                   SPY   SPY_lag1       SP500      NASDAQ         DJI  \
# 2022-06-07   5.651008  -6.474963  -38.250000 -274.520508 -249.007812
# 2022-06-08  -4.449112   5.651008   50.649902  221.470703  304.039062
# 2022-06-09 -14.016096  -4.449112  -45.470215 -130.810547 -258.449219
# 2022-06-10 -14.568685 -14.016096 -127.260010 -472.589844 -775.101562
# 2022-06-13  -2.907867 -14.568685 -136.239990 -557.030273 -908.609375
#
#                  CAC40         DAX        AORD         HSI      Nikkei  \
# 2022-06-07  -10.659668   -7.570312 -114.500000  -45.810547  -40.839844
# 2022-06-08   -5.610352   26.480469   28.399902  225.699219  134.029297
# 2022-06-09 -104.969727 -231.190430 -106.600098 -252.478516   57.179688
# 2022-06-10  -96.169922 -254.559570  -95.199707  283.679688 -172.060547
# 2022-06-13 -228.360352 -545.560547  -95.199707  -94.949219 -382.220703
#
#                  Price
# 2022-06-07  395.572628
# 2022-06-08  401.223635
# 2022-06-09  396.774523
# 2022-06-10  382.758427
# 2022-06-13  368.189742

# %%
num_rows = training_data.shape[0]
print(f"Number of rows in training_data: {num_rows}")
# Out:
# Number of rows in training_data: 617

# %%
#we are using this dataset to test our accuracy with already known data
test_start = dt.date(2022, 1, 1)
test_end = dt.date(2024, 6, 17)

testing_data = indicepanel.loc[test_start:test_end]
testing_data.tail()
# Out:
#                  SPY  SPY_lag1      SP500      NASDAQ         DJI       CAC40  \
# 2024-06-11  7.559998  0.890015  11.779785   76.970703   10.812500  108.569824
# 2024-06-12  1.520020  7.559998  56.129883  341.730469  154.937500 -107.319824
# 2024-06-13 -2.270020  1.520020  32.800293  213.119141 -273.527344   41.600098
# 2024-06-14  1.200012 -2.270020 -17.850098  -94.089844 -148.730469 -169.870117
# 2024-06-17  5.079956  1.200012   7.029785   76.121094   36.789062 -146.470215
#
#                    DAX        AORD        HSI      Nikkei       Price
# 2024-06-11  -52.480469 -106.899902  13.220703  -40.800781  534.070007
# 2024-06-12 -129.330078  -42.699707 -94.560547   11.562500  541.630005
# 2024-06-13  263.490234   39.399902   8.500000 -461.589844  543.150024
# 2024-06-14 -364.330078  -27.700195 -86.291016  226.988281  540.880005
# 2024-06-17 -259.449219  -31.199707  87.250000 -338.539062  542.080017

# %%
num_rows = testing_data.shape[0]
print(f"Number of rows in testing_data: {num_rows}")
# Out:
# Number of rows in testing_data: 617

# %%
print(training_data.shape, testing_data.shape)
# Out:
# (617, 11) (617, 11)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix = scatter_matrix(testing_data, figsize=(10,10))

# %%
plt.figure(figsize = (10, 4))
heatmap = sns.heatmap(testing_data.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %%
#I want to be weary of multicolinearity when building my multi linear regression
#therefore I will choose predictors that are relevant and less correlated to each other
from sklearn.linear_model import LinearRegression
X_train = training_data[['HSI','DAX', 'CAC40','SPY_lag1']]
Y_train = training_data['SPY']

model = LinearRegression()
model.fit(X_train, Y_train)

coefficients = model.coef_
intercept = model.intercept_

print(model.intercept_)
print(model.coef_)
# Out:
# 0.061065277841372015
# [-0.00202472 -0.00178416  0.00314022 -0.01903147]

# %%
X_test = testing_data[['HSI','DAX', 'CAC40','SPY_lag1']]
Y_test = testing_data['SPY']
predictions = model.predict(X_test)

# %%
plt.figure(figsize=(10, 6))

# Scatter plot of actual values
plt.scatter(testing_data.index, Y_test, color='blue', label='Actual')

# Line plot of predictions
plt.plot(testing_data.index, predictions, color='red', linewidth=2, label='Predicted')

plt.title('Predicted vs Actual SPY Values')
plt.xlabel('Index')
plt.ylabel('SPY Value')
plt.legend()
plt.grid(True)

# %%
print(predictions)
# Out:
# [ 4.67641665e-01  2.52545120e-01  8.97544001e-01 -2.30114976e-01
#  -1.97123109e-01 -3.23930725e-01 -1.39781902e-01 -8.14433169e-01
#   4.23608461e-01 -3.42394538e-01  6.26877779e-01  4.38808019e-01
#  -1.33693371e+00  9.19517666e-03  5.01900426e-01  2.46813579e-01
#  -1.12728768e-01  4.07370532e-01  8.97881748e-01 -6.38047168e-01
#  -6.36627876e-01 -3.06024215e-01 -2.81034715e-03 -1.48425269e-01
#   2.06928116e-01  6.17863297e-01 -2.98837478e-01  1.33437952e-01
#   2.49648419e-02  5.96515784e-01  6.12171368e-02 -2.15859493e-01
#  -5.21394937e-02  8.64188730e-01  8.75396566e-01 -2.05776764e-01
#   1.60651278e+00 -1.87180190e-01  3.21835034e-01 -2.08585385e-01
#   6.78060527e-01 -2.56236013e-02  5.03204247e-01  8.08610250e-01
#   8.73621600e-01  8.88701207e-02  2.39169031e-01 -7.60516785e-02
#   1.14170378e+00  1.21817935e+00 -2.67218971e+00 -1.86102416e-01
#  -1.94673599e-01  1.12588451e+00 -1.15481952e+00 -1.12325210e-01
#   3.43259816e-01  5.12770394e-01 -5.36504446e-01 -4.86211993e-01
#  -1.20936325e-01  6.73683155e-01 -4.22260299e-01 -4.78057326e-01
#  -4.67926244e-01  3.77630423e-01  3.47427128e-01 -5.25725520e-01
#   1.36257910e+00  3.99840428e-02 -1.99309064e-01 -9.45167813e-02
#   1.31647150e-01  2.36642362e-01 -1.84534441e-01  1.01715102e-01
#  -4.63866783e-01  1.35508831e+00  2.88204362e-02  6.05756065e-02
#  -3.20282607e-01 -1.83949470e+00 -1.48323638e+00 -2.95921377e-01
#   2.86703729e-01  4.15805661e-01  9.64655505e-01  7.69452961e-01
#  -6.42989437e-01 -4.52504669e-01  5.79943335e-01 -8.52093918e-01
#   3.08215228e-01 -8.42136529e-01  1.46885461e-01  5.53179248e-01
#  -7.02419755e-01  1.14555417e-01  7.18200479e-01  3.40976829e-02
#   2.70345090e-01 -2.32993151e-01 -5.87224270e-01  2.25750138e-01
#   7.20909495e-02 -7.85843047e-02 -7.55083751e-01  2.57079780e-01
#  -5.68322716e-01  7.39789400e-01 -9.43796473e-02  7.86839755e-01
#  -5.23136896e-01 -3.38341003e-01  1.55568217e+00 -2.85036340e-01
#  -7.49168685e-01  1.30335669e+00 -3.18446767e-01 -2.14468195e-01
#  -5.20579261e-01 -5.81558642e-01  5.56752551e-01  4.98016939e-01
#   3.10244069e-01  5.57981858e-01  4.67096070e-01 -5.32823715e-01
#   4.69068423e-01  5.81225177e-01  3.94559012e-01  5.35090977e-01
#   1.87028644e-01  5.61086351e-01 -1.03081045e+00  1.89749398e-01
#  -1.18468071e-01  4.60782430e-01  3.82693745e-01  9.59385380e-02
#  -2.82546999e-01  6.27930828e-02  2.97027852e-01  1.04408654e+00
#  -3.53313371e-01  5.97934326e-01  2.10773349e-01 -5.28039614e-01
#   4.02810781e-01 -1.17557356e-01  2.02590420e-01  8.84358407e-01
#  -6.86049232e-01  8.83189423e-02 -1.48527984e-01  5.58051361e-01
#   1.90008073e-01  7.49429587e-01 -5.96241966e-02  2.55815908e-02
#   6.03360889e-01  6.91226249e-01 -1.14932394e+00 -1.26918197e-01
#   4.42281049e-01  2.54251158e-01 -8.31650201e-01  5.69869057e-01
#   9.35197592e-02  4.58444354e-01 -1.57157269e-01  2.11598962e-01
#  -9.05431554e-01 -1.11909913e+00  2.20553931e-01  4.71603721e-01
#   6.05382568e-02  1.88353303e-01  4.26643243e-01 -3.36780880e-01
#   4.70585790e-01  1.44976237e-01  3.94774227e-01 -2.71700494e-02
#   1.21895354e-02  1.22518897e+00  7.93103665e-01  7.49569257e-02
#   1.67449266e-01 -4.29618289e-01 -5.02264315e-01  2.23619537e-01
#   4.40003848e-01  7.21348917e-01  8.82828054e-01  2.50285591e-01
#   8.70149276e-01 -3.60320426e-01 -2.94310105e-02 -3.60867545e-01
#   7.01606656e-01  7.08645576e-02  3.57494144e-01  1.07183748e+00
#   2.92870884e-01 -3.73011877e-01  4.81181913e-01  1.20744722e+00
#   1.80940405e-01 -1.21752278e+00 -6.84913947e-01  5.52585249e-01
#  -1.36495637e+00 -1.17013467e+00  1.25095272e-02  3.23585051e-01
#   2.04639705e-02 -8.43108799e-01  6.31727294e-01 -1.51671047e+00
#   2.59357183e-02  2.06255938e-01  6.18752783e-01 -4.30459818e-03
#   5.65676872e-01 -1.65845569e-01  1.41759587e-01 -4.55558382e-01
#  -1.04419988e+00 -8.33028696e-01  5.07198482e-01  3.69239156e-01
#  -6.10349998e-01 -3.36408173e-01  1.54033782e+00 -9.46154729e-01
#  -8.80912351e-01  3.11795646e-01 -5.23124479e-01  4.09810245e-01
#   7.05767851e-01  1.16862657e-01  3.03761495e-01  2.89139043e-01
#   1.05540008e-03 -1.50781160e-01 -2.36879448e-01 -4.60371195e-01
#  -7.03338946e-02 -1.10692199e-01  4.87929469e-01 -1.20733190e+00
#  -8.91077110e-01  5.16506775e-01  5.52430398e-01 -3.03124613e-01
#   9.95916685e-02 -9.80851954e-02  6.81960635e-02 -1.81975070e-01
#   1.42811164e-01 -2.58412183e-01 -1.22274067e-01 -3.54142880e-01
#  -6.36226119e-01 -4.42264182e-01 -2.59391832e-01 -4.11523590e-01
#  -7.44123523e-02  1.09307087e+00  8.42834208e-01 -3.62069127e-01
#   3.28602062e-01  2.71918576e-01  5.68757699e-01 -4.27778580e-02
#  -6.80464272e-02 -1.11611853e+00  1.13958632e+00 -3.55120837e-01
#   3.32725134e-01  6.80386952e-01  5.70552579e-02  9.14079512e-01
#   7.86887054e-01  3.81871601e-01 -1.15908839e-01  6.81073013e-01
#  -3.68681903e-01  7.10149075e-01 -1.56104385e+00  1.17292155e-01
#   1.71521087e-01 -4.44898267e-01  5.31669846e-02  6.28865389e-01
#   2.26962065e-01  8.09362782e-01 -4.02679112e-01  6.33289047e-01
#   1.25652943e-01 -3.43729244e-02 -1.15089121e-01  8.77350255e-01
#  -3.70776239e-01 -4.46757040e-01 -7.07204962e-01  1.75007856e-01
#   5.07182705e-01 -1.75725094e-01  3.08815845e-01 -2.80962721e-01
#   3.26777506e-01  4.54822757e-02  2.70163058e-01  2.80308192e-01
#  -2.14094398e-01 -2.32479057e-01  2.76633096e-03  4.63696518e-01
#  -4.95180237e-01 -2.81018545e-02 -7.35547988e-01 -1.01056673e-01
#   7.12683377e-01  5.35339341e-03  7.34180956e-01  1.04035594e-01
#   6.38694544e-01 -3.86800358e-01 -1.84020642e-01 -4.63687174e-02
#  -3.68010877e-02  2.40202964e-01  2.36647982e-01 -4.72927716e-01
#  -3.15332715e-02 -4.63693154e-01  8.63285332e-01  1.32615687e-01
#   2.87862854e-01  6.47543375e-01 -8.34366875e-01  4.62900811e-01
#   8.18826054e-01 -1.73489029e-01 -6.67506865e-02 -3.24301735e-01
#   7.16359618e-01  3.22587693e-01  4.89854568e-01  4.46773143e-01
#  -1.56068798e-01  4.11600386e-01  4.47454092e-02 -1.06754548e+00
#  -7.77644624e-02  4.78451426e-02  1.02167402e-01  2.73655977e-02
#  -8.08494666e-02  7.07582876e-02 -5.25906808e-01  3.11512727e-01
#  -3.92410310e-01 -3.81092499e-01  8.35353766e-01  2.00413056e-01
#   4.12322167e-01  4.94410364e-01  1.84424006e-01 -4.17340083e-01
#  -1.05420315e-01  6.16040484e-01 -2.60756695e-02 -7.00122700e-01
#   6.49813512e-01  6.57787888e-01  3.11175872e-01  4.35064939e-01
#   1.02508549e-01 -2.01308426e-01 -2.76830772e-01  7.75076484e-02
#   4.02298369e-01  5.02563899e-01 -2.61012127e-01  2.50380750e-01
#  -9.55998954e-02  5.24062041e-01 -4.17754684e-01 -2.94840086e-01
#  -2.78927780e-01 -9.50486445e-01  2.88805226e-01  5.38729229e-01
#   1.07021850e+00  2.11936782e-01  3.06531097e-01  5.18948223e-02
#   2.80563294e-01 -1.71967939e-01 -1.07931201e-01  6.80234267e-01
#  -1.13948741e-01 -6.00247015e-03  1.55795282e-01 -5.41528702e-01
#   7.30248027e-01  3.84231489e-01 -3.11973265e-01 -8.55631655e-02
#  -5.53787530e-01  1.86379367e-01  7.68261209e-01 -3.93481350e-01
#   2.49167078e-01  3.83575849e-01  2.41443268e-01  6.60668333e-01
#  -2.98951361e-02  5.66584394e-01  4.66569668e-01 -1.80095125e-01
#   1.04013632e-01  3.91156633e-01  8.37749389e-02  1.43204291e-02
#   4.77097647e-01 -6.38910229e-02  2.08421215e-01  5.12067607e-01
#  -8.30013321e-01  6.95084610e-01  5.52345580e-01 -3.84898323e-02
#   5.11188663e-01 -7.44395197e-01 -5.44597317e-01  5.66047088e-01
#   4.00147103e-01  9.53138367e-03 -8.15456128e-02 -7.96792254e-02
#  -3.16426706e-03 -1.81385369e-02  4.04242705e-02  3.62818452e-01
#   5.27954574e-01  1.18856451e-01 -1.67805178e-02  6.21089167e-01
#   1.87295632e-01  8.41566968e-02  3.05820403e-01  7.06512881e-01
#   4.81187040e-01 -2.88516190e-01 -5.43798215e-01  5.63485391e-01
#   1.14075412e-01 -5.54626681e-02 -5.97039676e-01 -1.75624717e-01
#   3.62297602e-01  1.16309512e-01  1.46560547e-01  4.28418002e-01
#  -3.40252079e-01  8.54854740e-02 -6.24287865e-01  4.23720661e-01
#   2.43421121e-01 -2.63358370e-01  3.85056730e-01  6.14915831e-06
#   4.70986582e-01  3.99907417e-01  3.77366053e-01  6.44906575e-01
#  -2.54665105e-01  4.60937141e-01  4.35795821e-01  5.69512134e-01
#  -3.48392600e-01  1.32194731e-01  1.43605697e-01 -1.37751097e-03
#  -2.94756214e-01  1.47628009e-01 -3.44328346e-02 -1.18645011e-01
#   2.22554417e-01  1.63914142e-01 -5.65544052e-03 -1.44727942e-01
#   8.29596541e-01  8.73612009e-01 -1.26983689e-01 -7.66599244e-01
#   6.02421632e-02  7.60993007e-01 -1.84174439e-02  2.04176546e-01
#   1.90510891e-01  5.88772800e-01  6.72146955e-02  9.27194067e-02
#  -3.14436341e-01  5.82815793e-02  5.19814620e-01  1.12693597e+00
#  -1.30677582e-01  1.69125706e-01  5.90951692e-01 -6.61027590e-01
#  -7.93624152e-01 -3.80347798e-01  7.62775672e-01  1.89220580e-01
#   3.36151799e-01  5.67055828e-01 -2.29494434e-02  2.67917360e-01
#  -3.76593559e-01 -1.07953859e+00  3.12314932e-01  3.88235808e-01
#  -2.03598838e-02  5.18823045e-03  1.38576762e-01 -6.33463157e-01
#  -1.37843321e-01 -6.70211412e-01  1.69997594e-01 -4.89629899e-01
#  -7.83375733e-01 -1.18910647e-01  2.25581666e-01 -3.37991690e-01
#   5.05801748e-01 -1.92168696e-01 -7.11352110e-01  1.09235509e-01
#   6.09736454e-01 -5.64648131e-01  4.57425227e-01 -2.08355594e-01
#  -1.07649473e-02 -7.91001988e-01 -2.02155187e-01  5.21806120e-01
#   3.66223479e-01 -6.25125232e-02  2.07546029e-01 -6.17675477e-02
#  -9.58969858e-02  5.65761757e-02  1.62788122e-01 -1.66661683e-01
#   1.90825141e-01 -3.65700993e-01 -3.48953210e-01 -1.68076004e-01
#   6.95905761e-01  2.37996147e-01 -2.72621596e-02  2.30433396e-01
#  -1.32167556e-01  2.23612377e-01 -6.61878213e-01  9.78391195e-01
#  -2.61199637e-01 -1.32479914e-01  6.33031699e-01  2.36186337e-02
#  -8.42718310e-02  3.63090994e-01 -5.48618325e-01 -8.20575927e-01
#  -2.34897239e-02 -4.84428866e-01 -3.20228801e-01  1.93949707e-01
#   3.01477375e-01 -9.42702668e-01  9.58088736e-02 -2.49655306e-01
#   6.79675139e-02  2.26612815e-01 -4.74015768e-01 -6.14357809e-01
#  -6.01273577e-01  4.27426480e-01  3.50788557e-01 -5.28917193e-01
#   1.14294404e-01  2.79960803e-02  4.26002437e-01  5.24224625e-02
#   3.43863806e-01  2.60515267e-01  1.69666885e-02  3.74647402e-01
#   4.80980618e-01  8.75053163e-01  5.34922736e-03 -5.95573618e-01
#   4.98082095e-01  7.31299948e-02  3.60989769e-01 -9.37862880e-02
#   4.51926069e-01  2.38351579e-03 -3.24548587e-01  3.95575696e-01
#  -1.35479603e-01]

# %%
from sklearn.metrics import mean_squared_error, r2_score

RMSE = np.sqrt(mean_squared_error(Y_test, predictions))
R2 = r2_score(Y_test, predictions)

print(f"RMSE: {RMSE}")
print(f"R-squared: {R2}")
# Out:
# RMSE: 4.681638507417525
# R-squared: 0.006017151045395908

# %%
RMSE = np.sqrt(mean_squared_error(Y_train, predictions))
R2 = r2_score(Y_train, predictions)

print(f"RMSE: {RMSE}")
print(f"R-squared: {R2}")
# Out:
# RMSE: 4.819093936485879
# R-squared: -0.02503671754058434

# %%
#negative R square in the training indicates the test has preformed better and our model is not overfitted.

# %%
training_data['Order'] = [1 if sig > 0 else -1 for sig in Y_train]
training_data['Profit'] = training_data['SPY']*training_data['Order']

training_data['Cummulative Profit'] = training_data['Profit'].cumsum()
print("Total profit during training: ", training_data['Profit'].sum())
# Out:
# Total profit during training:  2094.484659732135
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\691361243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Order'] = [1 if sig > 0 else -1 for sig in Y_train]
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\691361243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Profit'] = training_data['SPY']*training_data['Order']
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\691361243.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Cummulative Profit'] = training_data['Profit'].cumsum()

# %%
plt.figure(figsize=(10, 10))
plt.title('Performance of Strategy in Train')
plt.plot(training_data['Cummulative Profit'].values, color='green', label='Signal based strategy')
plt.plot(training_data['SPY'].cumsum().values, color='red', label='Buy and Hold strategy')
plt.legend()
plt.show()

# %%
testing_data['Order'] = [1 if sig > 0 else -1 for sig in predictions]
testing_data['Profit'] = testing_data['SPY'] * testing_data['Order']
testing_data['Cummulative Profit'] = testing_data['Profit'].cumsum()

print("Total profit during testing: ", testing_data['Profit'].sum())
# Out:
# Total profit during testing:  119.99538421889838
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\3005441123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Order'] = [1 if sig > 0 else -1 for sig in predictions]
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\3005441123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Profit'] = testing_data['SPY'] * testing_data['Order']
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\3005441123.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Cummulative Profit'] = testing_data['Profit'].cumsum()

# %%
plt.figure(figsize=(10, 10))
plt.title('Performance of Strategy in Testing')
plt.plot(testing_data['Cummulative Profit'].values, color='green', label='Signal based strategy')
plt.plot(testing_data['SPY'].cumsum().values, color='red', label='Buy and Hold strategy')
plt.legend()
plt.show()

# %%
#with our prediction, the signal trading strategy is more profitable than buying and holding the stock over time.
#using Sharpe Ratio and Maximum drawdown for evaluating the model
#Sharpe Ratio = mean of excess return/SD of excess return
#measures the excess return per unit of deviation in an investment asset or a trading strategy. Understand the return of an investment compared to its risk.
training_cumulative_profit = training_data['Cummulative Profit']
training_returns = training_cumulative_profit.diff() 
training_returns.iloc[0] = training_cumulative_profit.iloc[0]

testing_cumulative_profit = testing_data['Cummulative Profit']
testing_returns = testing_cumulative_profit.diff()
testing_returns.iloc[0] = testing_cumulative_profit.iloc[0]

R_f = 0.02
R_f_daily = R_f / 252

sharpe_ratio_training = np.sqrt(252) * (training_returns.mean() - R_f_daily) / training_returns.std()
sharpe_ratio_testing = np.sqrt(252) * (testing_returns.mean() - R_f_daily) / testing_returns.std()

print("Sharpe Ratio during training: ", sharpe_ratio_training)
print("Sharpe Ratio during testing: ", sharpe_ratio_testing)
# Out:
# Sharpe Ratio during training:  16.129674633573877
# Sharpe Ratio during testing:  0.6569296686532162

# %%
#testing is not as favorable for this trading strategy 
#signs of overfitting 
#maximum drawdown is the max percentage decline from historical peak profit at each point in time
# = (peak value - trough value)/peak value
training_data['Peak Value'] = training_cumulative_profit.cummax()
training_data['Drawdown'] = (training_data['Peak Value'] - training_cumulative_profit)/training_data['Peak Value']
                                                                                
print('Maximum Drawdown in Train is ', training_data['Drawdown'].max())
# Out:
# Maximum Drawdown in Train is  0.0
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\959291223.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Peak Value'] = training_cumulative_profit.cummax()
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\959291223.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Drawdown'] = (training_data['Peak Value'] - training_cumulative_profit)/training_data['Peak Value']

# %%
testing_data['Peak Value'] = testing_cumulative_profit.cummax()
testing_data['Drawdown'] = (testing_data['Peak Value'] - testing_cumulative_profit)/testing_data['Peak Value']
                                                                                
print('Maximum Drawdown in Test is ', testing_data['Drawdown'].max())
# Out:
# Maximum Drawdown in Test is  12.547924971072868
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\4267435251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Peak Value'] = testing_cumulative_profit.cummax()
# C:\Users\leoju\AppData\Local\Temp\ipykernel_5656\4267435251.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Drawdown'] = (testing_data['Peak Value'] - testing_cumulative_profit)/testing_data['Peak Value']
